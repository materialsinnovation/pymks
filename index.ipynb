# %%
import pymks
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-877470d44e8a> in <module>()
# ----> 1 import pymks
#
# ImportError: No module named pymks
